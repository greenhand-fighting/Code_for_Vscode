# %%
import input, draw, calulate
import CCRRT, CLRRT, PURRT
import numpy as np
car=CCRRT.Vehicle(input.ego_car_size[0],input.ego_car_size[1],input.ego_car_size[2])
# 值的传递：
s=input.starting_point
g=input.goal_point
r=input.random_sample_area
rt=input.rengong_tuoyuan
gk=input.ganzhi_kuang
gt=input.ganzhi_tuoyuan
zk=input.zhenzhi_kuang
# 值传递完毕

maxcc_list_100times=[]
mincc_list_100times=[]
avgcc_list_100times=[]
long_list_100times = []
pointnumber_list_100times = []
fail=0
for i in range(100):
    #nt(i)
    cc_rrt=CCRRT.CcrrtGo(car=car,start=s,goal=g, rand_area=r
                    ,rengong_tuoyuan=rt,ganzhi_tuoyuan=gt, ganzhi_kuang=gk)
    cc_rrt.planning(animation=False)
  #  print("有多少路径 %f   fail : %d" % (len(cc_rrt.path_end),fail))
    computer=calulate.calulate_path_info(cc_rrt)
    pengzhuang=0
    for node_in_final_path in cc_rrt.path:
        if cc_rrt.peng_zhuang_jian_ce(node_in_final_path, zk):  # 这个函数的参数第一个是节点，第二个是列表，列表是【障碍物x，障碍物y，长半轴，短半轴，yaw】！！！！！！！！！！！！！！！！！！！
            pengzhuang=1
            break
    if pengzhuang==0 and len(cc_rrt.path_end):
        long_list_100times.append(computer.path_length)
        maxcc_list_100times.append(computer.path_max)
        mincc_list_100times.append(computer.path_min)
        avgcc_list_100times.append(computer.path_avg)
        pointnumber_list_100times.append(computer.path_points_number)
        pass
    else:
        fail+=1 
pointnumber_list_100times=np.array(pointnumber_list_100times)
long_list_100times=np.array(long_list_100times)
maxcc_list_100times=np.array(maxcc_list_100times)
mincc_list_100times=np.array(mincc_list_100times)
avgcc_list_100times=np.array(avgcc_list_100times)
print("max: %f" % np.average(maxcc_list_100times))
print("avg: %f" % np.average(avgcc_list_100times))
print("min: %f" % np.average(mincc_list_100times))
print("points: %f" % np.average(pointnumber_list_100times))
print("changdu: %f" % np.average(long_list_100times))
print('*'*100)
print("fail=:= %f" % fail)
success_rate = (100 - fail) / 100
print("ccrrt success2 rate: %f" % success_rate)


# maxcc_list_100times=[]
# mincc_list_100times=[]
# avgcc_list_100times=[]
# long_list_100times = []
# pointnumber_list_100times = []
# fail=0
# for i in range(100):
# #    print(i)
#     cc_rrt=PURRT.PurrtGo(car=car,start=s,goal=g, rand_area=r
#                     ,rengong_tuoyuan=rt,ganzhi_tuoyuan=gt, ganzhi_kuang=gk)
#     cc_rrt.planning(animation=False)
# #    print("有多少路径 %f   fail : %d" % (len(cc_rrt.path_end),fail))
#     computer=calulate.calulate_path_info(cc_rrt)
#     pengzhuang=0
#     for node_in_final_path in cc_rrt.path:
#         if cc_rrt.peng_zhuang_jian_ce(node_in_final_path, zk):  # 这个函数的参数第一个是节点，第二个是列表，列表是【障碍物x，障碍物y，长半轴，短半轴，yaw】！！！！！！！！！！！！！！！！！！！
#             pengzhuang=1
#             break
#     if pengzhuang==0 and len(cc_rrt.path_end):
#         long_list_100times.append(computer.path_length)
#         maxcc_list_100times.append(computer.path_max)
#         mincc_list_100times.append(computer.path_min)
#         avgcc_list_100times.append(computer.path_avg)
#         pointnumber_list_100times.append(computer.path_points_number)
#         pass
#     else:
#         fail+=1 
# pointnumber_list_100times=np.array(pointnumber_list_100times)
# long_list_100times=np.array(long_list_100times)
# maxcc_list_100times=np.array(maxcc_list_100times)
# mincc_list_100times=np.array(mincc_list_100times)
# avgcc_list_100times=np.array(avgcc_list_100times)
# print("max: %f" % np.average(maxcc_list_100times))
# print("avg: %f" % np.average(avgcc_list_100times))
# print("min: %f" % np.average(mincc_list_100times))
# print("points: %f" % np.average(pointnumber_list_100times))
# print("changdu: %f" % np.average(long_list_100times))
# print('*'*100)
# print("fail=:= %f" % fail)
# success_rate = (100 - fail) / 100
# print("purrt success2 rate: %f" % success_rate)

# maxcc_list_100times=[]
# mincc_list_100times=[]
# avgcc_list_100times=[]
# long_list_100times = []
# pointnumber_list_100times = []
# fail=0
# for i in range(100):
#  #   print(i)
#     cc_rrt=CLRRT.ClrrtGo(car=car,start=s,goal=g, rand_area=r
#                     ,rengong_tuoyuan=rt,ganzhi_tuoyuan=gt, ganzhi_kuang=gk)
#     cc_rrt.planning(animation=False)
#  #   print("有多少路径 %f   fail : %d" % (len(cc_rrt.path_end),fail))
#     computer=calulate.calulate_path_info(cc_rrt)
#     pengzhuang=0
#     for node_in_final_path in cc_rrt.path:
#         if cc_rrt.peng_zhuang_jian_ce(node_in_final_path, zk):  # 这个函数的参数第一个是节点，第二个是列表，列表是【障碍物x，障碍物y，长半轴，短半轴，yaw】！！！！！！！！！！！！！！！！！！！
#             pengzhuang=1
#             break
#     if pengzhuang==0 and len(cc_rrt.path_end):
#         long_list_100times.append(computer.path_length)
#         maxcc_list_100times.append(computer.path_max)
#         mincc_list_100times.append(computer.path_min)
#         avgcc_list_100times.append(computer.path_avg)
#         pointnumber_list_100times.append(computer.path_points_number)
#         pass
#     else:
#         fail+=1 
# pointnumber_list_100times=np.array(pointnumber_list_100times)
# long_list_100times=np.array(long_list_100times)
# maxcc_list_100times=np.array(maxcc_list_100times)
# mincc_list_100times=np.array(mincc_list_100times)
# avgcc_list_100times=np.array(avgcc_list_100times)
# print("max: %f" % np.average(maxcc_list_100times))
# print("avg: %f" % np.average(avgcc_list_100times))
# print("min: %f" % np.average(mincc_list_100times))
# print("points: %f" % np.average(pointnumber_list_100times))
# print("changdu: %f" % np.average(long_list_100times))
# print('*'*100)
# print("fail=:= %f" % fail)
# success_rate = (100 - fail) / 100
# print("clrrt success2 rate: %f" % success_rate)
# Out:
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 286
# Iter: 20 , number of nodes: 607
# Iter: 30 , number of nodes: 1016
# Iter: 40 , number of nodes: 1459
# Iter: 50 , number of nodes: 1826
# Iter: 60 , number of nodes: 2202
# Iter: 70 , number of nodes: 2545
# Tree with 3002 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 177
# Iter: 20 , number of nodes: 467
# Iter: 30 , number of nodes: 799
# Iter: 40 , number of nodes: 1130
# Iter: 50 , number of nodes: 1568
# Iter: 60 , number of nodes: 2002
# Iter: 70 , number of nodes: 2455
# Tree with 2780 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 134
# Iter: 20 , number of nodes: 324
# Iter: 30 , number of nodes: 651
# Iter: 40 , number of nodes: 948
# Iter: 50 , number of nodes: 1360
# Iter: 60 , number of nodes: 1836
# Iter: 70 , number of nodes: 2216
# Tree with 2488 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 131
# Iter: 20 , number of nodes: 457
# Iter: 30 , number of nodes: 716
# Iter: 40 , number of nodes: 1159
# Iter: 50 , number of nodes: 1640
# Iter: 60 , number of nodes: 1923
# Iter: 70 , number of nodes: 2294
# Tree with 2656 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 61
# Iter: 20 , number of nodes: 215
# Iter: 30 , number of nodes: 489
# Iter: 40 , number of nodes: 848
# Iter: 50 , number of nodes: 1267
# Iter: 60 , number of nodes: 1557
# Iter: 70 , number of nodes: 1977
# Tree with 2400 nodes generated
# 1 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 169
# Iter: 20 , number of nodes: 588
# Iter: 30 , number of nodes: 901
# Iter: 40 , number of nodes: 1335
# Iter: 50 , number of nodes: 1782
# Iter: 60 , number of nodes: 2186
# Iter: 70 , number of nodes: 2551
# Tree with 3001 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 111
# Iter: 20 , number of nodes: 381
# Iter: 30 , number of nodes: 522
# Iter: 40 , number of nodes: 898
# Iter: 50 , number of nodes: 1209
# Iter: 60 , number of nodes: 1494
# Iter: 70 , number of nodes: 1806
# Tree with 2048 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 35
# Iter: 20 , number of nodes: 114
# Iter: 30 , number of nodes: 306
# Iter: 40 , number of nodes: 599
# Iter: 50 , number of nodes: 817
# Iter: 60 , number of nodes: 1061
# Iter: 70 , number of nodes: 1331
# Tree with 1590 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 68
# Iter: 20 , number of nodes: 365
# Iter: 30 , number of nodes: 727
# Iter: 40 , number of nodes: 1124
# Iter: 50 , number of nodes: 1452
# Iter: 60 , number of nodes: 1820
# Iter: 70 , number of nodes: 2240
# Tree with 2758 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 131
# Iter: 20 , number of nodes: 370
# Iter: 30 , number of nodes: 691
# Iter: 40 , number of nodes: 1151
# Iter: 50 , number of nodes: 1651
# Iter: 60 , number of nodes: 2130
# Iter: 70 , number of nodes: 2531
# Tree with 2966 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 239
# Iter: 20 , number of nodes: 553
# Iter: 30 , number of nodes: 823
# Iter: 40 , number of nodes: 996
# Iter: 50 , number of nodes: 1313
# Iter: 60 , number of nodes: 1723
# Iter: 70 , number of nodes: 2230
# Tree with 2690 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 129
# Iter: 20 , number of nodes: 392
# Iter: 30 , number of nodes: 729
# Iter: 40 , number of nodes: 1123
# Iter: 50 , number of nodes: 1501
# Iter: 60 , number of nodes: 1935
# Iter: 70 , number of nodes: 2249
# Tree with 2533 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 111
# Iter: 20 , number of nodes: 432
# Iter: 30 , number of nodes: 677
# Iter: 40 , number of nodes: 1128
# Iter: 50 , number of nodes: 1437
# Iter: 60 , number of nodes: 1767
# Iter: 70 , number of nodes: 2115
# Tree with 2573 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 354
# Iter: 20 , number of nodes: 887
# Iter: 30 , number of nodes: 1211
# Iter: 40 , number of nodes: 1538
# Iter: 50 , number of nodes: 1882
# Iter: 60 , number of nodes: 2301
# Iter: 70 , number of nodes: 2661
# Tree with 3002 nodes generated
# 26 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 139
# Iter: 20 , number of nodes: 572
# Iter: 30 , number of nodes: 895
# Iter: 40 , number of nodes: 1297
# Iter: 50 , number of nodes: 1586
# Iter: 60 , number of nodes: 2016
# Iter: 70 , number of nodes: 2489
# Tree with 2986 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 61
# Iter: 20 , number of nodes: 226
# Iter: 30 , number of nodes: 380
# Iter: 40 , number of nodes: 665
# Iter: 50 , number of nodes: 955
# Iter: 60 , number of nodes: 1329
# Iter: 70 , number of nodes: 1739
# Tree with 2172 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 71
# Iter: 20 , number of nodes: 389
# Iter: 30 , number of nodes: 724
# Iter: 40 , number of nodes: 1047
# Iter: 50 , number of nodes: 1374
# Iter: 60 , number of nodes: 1768
# Iter: 70 , number of nodes: 2140
# Tree with 2430 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 111
# Iter: 20 , number of nodes: 425
# Iter: 30 , number of nodes: 754
# Iter: 40 , number of nodes: 1096
# Iter: 50 , number of nodes: 1485
# Iter: 60 , number of nodes: 1738
# Iter: 70 , number of nodes: 2003
# Tree with 2319 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 63
# Iter: 20 , number of nodes: 323
# Iter: 30 , number of nodes: 772
# Iter: 40 , number of nodes: 1155
# Iter: 50 , number of nodes: 1547
# Iter: 60 , number of nodes: 1867
# Iter: 70 , number of nodes: 2280
# Tree with 2509 nodes generated
# 2 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 274
# Iter: 20 , number of nodes: 559
# Iter: 30 , number of nodes: 919
# Iter: 40 , number of nodes: 1112
# Iter: 50 , number of nodes: 1601
# Iter: 60 , number of nodes: 1955
# Iter: 70 , number of nodes: 2389
# Tree with 2734 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 181
# Iter: 20 , number of nodes: 529
# Iter: 30 , number of nodes: 888
# Iter: 40 , number of nodes: 1295
# Iter: 50 , number of nodes: 1702
# Iter: 60 , number of nodes: 2082
# Iter: 70 , number of nodes: 2401
# Tree with 2748 nodes generated
# 13 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 91
# Iter: 20 , number of nodes: 518
# Iter: 30 , number of nodes: 793
# Iter: 40 , number of nodes: 1037
# Iter: 50 , number of nodes: 1373
# Iter: 60 , number of nodes: 1661
# Iter: 70 , number of nodes: 1995
# Tree with 2365 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 103
# Iter: 20 , number of nodes: 483
# Iter: 30 , number of nodes: 720
# Iter: 40 , number of nodes: 1004
# Iter: 50 , number of nodes: 1264
# Iter: 60 , number of nodes: 1613
# Iter: 70 , number of nodes: 1946
# Tree with 2279 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 182
# Iter: 20 , number of nodes: 773
# Iter: 30 , number of nodes: 1230
# Iter: 40 , number of nodes: 1548
# Iter: 50 , number of nodes: 1974
# Iter: 60 , number of nodes: 2497
# Tree with 3002 nodes generated
# 20 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 45
# Iter: 20 , number of nodes: 208
# Iter: 30 , number of nodes: 457
# Iter: 40 , number of nodes: 756
# Iter: 50 , number of nodes: 1051
# Iter: 60 , number of nodes: 1338
# Iter: 70 , number of nodes: 1919
# Tree with 2272 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 89
# Iter: 20 , number of nodes: 255
# Iter: 30 , number of nodes: 486
# Iter: 40 , number of nodes: 680
# Iter: 50 , number of nodes: 909
# Iter: 60 , number of nodes: 1259
# Iter: 70 , number of nodes: 1601
# Tree with 1867 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 83
# Iter: 20 , number of nodes: 441
# Iter: 30 , number of nodes: 834
# Iter: 40 , number of nodes: 1135
# Iter: 50 , number of nodes: 1494
# Iter: 60 , number of nodes: 1870
# Iter: 70 , number of nodes: 2170
# Tree with 2545 nodes generated
# 2 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 68
# Iter: 20 , number of nodes: 209
# Iter: 30 , number of nodes: 370
# Iter: 40 , number of nodes: 539
# Iter: 50 , number of nodes: 776
# Iter: 60 , number of nodes: 1075
# Iter: 70 , number of nodes: 1408
# Tree with 1783 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 158
# Iter: 20 , number of nodes: 486
# Iter: 30 , number of nodes: 846
# Iter: 40 , number of nodes: 1351
# Iter: 50 , number of nodes: 1803
# Iter: 60 , number of nodes: 2154
# Iter: 70 , number of nodes: 2481
# Tree with 2752 nodes generated
# 15 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 463
# Iter: 20 , number of nodes: 907
# Iter: 30 , number of nodes: 1219
# Iter: 40 , number of nodes: 1634
# Iter: 50 , number of nodes: 1957
# Iter: 60 , number of nodes: 2289
# Tree with 3001 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 172
# Iter: 20 , number of nodes: 471
# Iter: 30 , number of nodes: 748
# Iter: 40 , number of nodes: 1207
# Iter: 50 , number of nodes: 1616
# Iter: 60 , number of nodes: 2015
# Iter: 70 , number of nodes: 2410
# Tree with 2717 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 88
# Iter: 20 , number of nodes: 489
# Iter: 30 , number of nodes: 816
# Iter: 40 , number of nodes: 1164
# Iter: 50 , number of nodes: 1617
# Iter: 60 , number of nodes: 2043
# Iter: 70 , number of nodes: 2509
# Tree with 2899 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 169
# Iter: 20 , number of nodes: 518
# Iter: 30 , number of nodes: 804
# Iter: 40 , number of nodes: 1165
# Iter: 50 , number of nodes: 1429
# Iter: 60 , number of nodes: 1882
# Iter: 70 , number of nodes: 2303
# Tree with 2692 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 281
# Iter: 20 , number of nodes: 546
# Iter: 30 , number of nodes: 864
# Iter: 40 , number of nodes: 1242
# Iter: 50 , number of nodes: 1689
# Iter: 60 , number of nodes: 2099
# Iter: 70 , number of nodes: 2408
# Tree with 2780 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 145
# Iter: 20 , number of nodes: 378
# Iter: 30 , number of nodes: 647
# Iter: 40 , number of nodes: 966
# Iter: 50 , number of nodes: 1531
# Iter: 60 , number of nodes: 1930
# Iter: 70 , number of nodes: 2380
# Tree with 2773 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 86
# Iter: 20 , number of nodes: 390
# Iter: 30 , number of nodes: 652
# Iter: 40 , number of nodes: 1009
# Iter: 50 , number of nodes: 1278
# Iter: 60 , number of nodes: 1671
# Iter: 70 , number of nodes: 2075
# Tree with 2394 nodes generated
# 1 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 65
# Iter: 20 , number of nodes: 314
# Iter: 30 , number of nodes: 514
# Iter: 40 , number of nodes: 961
# Iter: 50 , number of nodes: 1329
# Iter: 60 , number of nodes: 1649
# Iter: 70 , number of nodes: 2060
# Tree with 2419 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 214
# Iter: 20 , number of nodes: 531
# Iter: 30 , number of nodes: 845
# Iter: 40 , number of nodes: 1231
# Iter: 50 , number of nodes: 1645
# Iter: 60 , number of nodes: 2202
# Iter: 70 , number of nodes: 2508
# Tree with 3001 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 55
# Iter: 20 , number of nodes: 186
# Iter: 30 , number of nodes: 539
# Iter: 40 , number of nodes: 897
# Iter: 50 , number of nodes: 1219
# Iter: 60 , number of nodes: 1408
# Iter: 70 , number of nodes: 1710
# Tree with 2181 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 163
# Iter: 20 , number of nodes: 347
# Iter: 30 , number of nodes: 648
# Iter: 40 , number of nodes: 935
# Iter: 50 , number of nodes: 1188
# Iter: 60 , number of nodes: 1600
# Iter: 70 , number of nodes: 1953
# Tree with 2303 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 180
# Iter: 20 , number of nodes: 385
# Iter: 30 , number of nodes: 646
# Iter: 40 , number of nodes: 940
# Iter: 50 , number of nodes: 1344
# Iter: 60 , number of nodes: 1663
# Iter: 70 , number of nodes: 1963
# Tree with 2396 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 210
# Iter: 20 , number of nodes: 432
# Iter: 30 , number of nodes: 797
# Iter: 40 , number of nodes: 1063
# Iter: 50 , number of nodes: 1319
# Iter: 60 , number of nodes: 1765
# Iter: 70 , number of nodes: 2060
# Tree with 2574 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 121
# Iter: 20 , number of nodes: 404
# Iter: 30 , number of nodes: 748
# Iter: 40 , number of nodes: 1135
# Iter: 50 , number of nodes: 1580
# Iter: 60 , number of nodes: 1977
# Iter: 70 , number of nodes: 2226
# Tree with 2654 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 158
# Iter: 20 , number of nodes: 481
# Iter: 30 , number of nodes: 757
# Iter: 40 , number of nodes: 1023
# Iter: 50 , number of nodes: 1381
# Iter: 60 , number of nodes: 1758
# Iter: 70 , number of nodes: 2221
# Tree with 2524 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 44
# Iter: 20 , number of nodes: 345
# Iter: 30 , number of nodes: 779
# Iter: 40 , number of nodes: 1049
# Iter: 50 , number of nodes: 1434
# Iter: 60 , number of nodes: 1851
# Iter: 70 , number of nodes: 2316
# Tree with 2611 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 73
# Iter: 20 , number of nodes: 241
# Iter: 30 , number of nodes: 480
# Iter: 40 , number of nodes: 717
# Iter: 50 , number of nodes: 1084
# Iter: 60 , number of nodes: 1371
# Iter: 70 , number of nodes: 1727
# Tree with 2104 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 34
# Iter: 20 , number of nodes: 114
# Iter: 30 , number of nodes: 356
# Iter: 40 , number of nodes: 524
# Iter: 50 , number of nodes: 828
# Iter: 60 , number of nodes: 1064
# Iter: 70 , number of nodes: 1384
# Tree with 1717 nodes generated
# No path found!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 231
# Iter: 20 , number of nodes: 590
# Iter: 30 , number of nodes: 837
# Iter: 40 , number of nodes: 1179
# Iter: 50 , number of nodes: 1607
# Iter: 60 , number of nodes: 1909
# Iter: 70 , number of nodes: 2323
# Tree with 2685 nodes generated
# 1 path be found
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 78
# Iter: 20 , number of nodes: 265
# Iter: 30 , number of nodes: 462
# Iter: 40 , number of nodes: 684
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2fa558cf7129> in <module>
#      23     cc_rrt=CCRRT.CcrrtGo(car=car,start=s,goal=g, rand_area=r
#      24                     ,rengong_tuoyuan=rt,ganzhi_tuoyuan=gt, ganzhi_kuang=gk)
# ---> 25     cc_rrt.planning(animation=False)
#      26   #  print("有多少路径 %f   fail : %d" % (len(cc_rrt.path_end),fail))
#      27     computer=calulate.calulate_path_info(cc_rrt)
#
# ~/code_for_vscode/sample_code/CCRRT.py in planning(self, animation, with_metric)
#     164
#     165                 # local planner sampling (also updates sample.conv)
# --> 166                 self.local_planner(nearest_node, sample_node)
#     167
#     168                 if len(self.path_end) > self.max_n_path or len(self.node_list) > self.max_n_node:
#
# ~/code_for_vscode/sample_code/CCRRT.py in local_planner(self, parent, sample)
#     331
#     332     def local_planner(self, parent, sample):
# --> 333         feasible_node_list = self.steer(parent, sample)
#     334         for node in feasible_node_list:
#     335             self.node_list.append(node)  # add to tree
#
# ~/code_for_vscode/sample_code/CCRRT.py in steer(self, from_node, to_node)
#     273                               self.sigma_pose
#     274             inter_node.cc = self.get_chance_constrain(inter_node)
# --> 275             if inter_node.cc < 1.0 - self.p_safe and self.in_place(inter_node) and self.safe_steer(inter_node):
#     276                 inter_node.time = prev.time + self.delta_time
#     277                 inter_node.cost = self.get_cost(inter_node.time, inter_node.cc)
#
# ~/code_for_vscode/sample_code/CCRRT.py in safe_steer(self, node)
#     809                     return False
#     810                 #cc检测
# --> 811                 if self.get_chance_constrain(t_node)>= 1-self.p_safe:
#     812                     return False
#     813         return True
#
# ~/code_for_vscode/sample_code/CCRRT.py in get_chance_constrain(self, current)
#     453                 sigma = current.conv + abs_mat
#     454                 # sigma = current.conv + np.diag([obs[2], obs[3], obs[4]]) # 3*3
# --> 455                 erf_item = (a.dot(x).item() - b) / np.sqrt(2 * a.dot(sigma).dot(a.transpose()).item())
#     456                 cc = 0.5 * (1 - erf(erf_item))
#     457                 if cc < delta_tj:
#
# KeyboardInterrupt:

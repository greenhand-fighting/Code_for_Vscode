# %%
print(1111111111)
# Out:
# 1111111111

# %%
import 时刻1.ccrrt_time1_sussess
# Out:
# , number of nodes: 2897
# Iter: 170 , number of nodes: 3114
# Iter: 180 , number of nodes: 3419
# Iter: 190 , number of nodes: 3633
# Tree with 3942 nodes generated
# No path found!
# because no path ::::fail=== 4.000000
# ****************************************************************************************************
# n lun : 70
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 44
# Iter: 20 , number of nodes: 186
# Iter: 30 , number of nodes: 335
# Iter: 40 , number of nodes: 595
# Iter: 50 , number of nodes: 748
# Iter: 60 , number of nodes: 962
# Iter: 70 , number of nodes: 1279
# Iter: 80 , number of nodes: 1516
# Iter: 90 , number of nodes: 1694
# Iter: 100 , number of nodes: 1921
# Iter: 110 , number of nodes: 2188
# Iter: 120 , number of nodes: 2489
# Iter: 130 , number of nodes: 2663
# Iter: 140 , number of nodes: 2876
# Iter: 150 , number of nodes: 3047
# Iter: 160 , number of nodes: 3246
# Iter: 170 , number of nodes: 3508
# Iter: 180 , number of nodes: 3662
# Iter: 190 , number of nodes: 3938
# Tree with 4225 nodes generated
# No path found!
# because no path ::::fail=== 4.000000
# ****************************************************************************************************
# n lun : 71
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 77
# Iter: 20 , number of nodes: 276
# Iter: 30 , number of nodes: 346
# Iter: 40 , number of nodes: 550
# Iter: 50 , number of nodes: 741
# Iter: 60 , number of nodes: 1104
# Iter: 70 , number of nodes: 1268
# Iter: 80 , number of nodes: 1443
# Iter: 90 , number of nodes: 1607
# Iter: 100 , number of nodes: 1826
# Iter: 110 , number of nodes: 1988
# Iter: 120 , number of nodes: 2276
# Iter: 130 , number of nodes: 2405
# Iter: 140 , number of nodes: 2580
# Iter: 150 , number of nodes: 2759
# Iter: 160 , number of nodes: 2856
# Iter: 170 , number of nodes: 3066
# Iter: 180 , number of nodes: 3297
# Iter: 190 , number of nodes: 3459
# Tree with 3569 nodes generated
# No path found!
# because no path ::::fail=== 4.000000
# ****************************************************************************************************
# n lun : 72
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 69
# Iter: 20 , number of nodes: 242
# Iter: 30 , number of nodes: 422
# Iter: 40 , number of nodes: 607
# Iter: 50 , number of nodes: 773
# Iter: 60 , number of nodes: 957
# Iter: 70 , number of nodes: 1128
# Iter: 80 , number of nodes: 1293
# Iter: 90 , number of nodes: 1434
# Iter: 100 , number of nodes: 1604
# Iter: 110 , number of nodes: 1779
# Iter: 120 , number of nodes: 1939
# Iter: 130 , number of nodes: 2102
# Iter: 140 , number of nodes: 2306
# Iter: 150 , number of nodes: 2505
# Iter: 160 , number of nodes: 2774
# Iter: 170 , number of nodes: 3031
# Iter: 180 , number of nodes: 3233
# Iter: 190 , number of nodes: 3431
# Tree with 3719 nodes generated
# No path found!
# because no path ::::fail=== 4.000000
# ****************************************************************************************************
# n lun : 73
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 28
# Iter: 20 , number of nodes: 558
# Iter: 30 , number of nodes: 1143
# Iter: 40 , number of nodes: 1541
# Iter: 50 , number of nodes: 1931
# Iter: 60 , number of nodes: 2116
# Iter: 70 , number of nodes: 2409
# Iter: 80 , number of nodes: 2567
# Iter: 90 , number of nodes: 2790
# Iter: 100 , number of nodes: 3009
# Iter: 110 , number of nodes: 3217
# Iter: 120 , number of nodes: 3363
# Iter: 130 , number of nodes: 3599
# Iter: 140 , number of nodes: 3752
# Iter: 150 , number of nodes: 4075
# Iter: 160 , number of nodes: 4296
# Iter: 170 , number of nodes: 4458
# Iter: 180 , number of nodes: 4638
# Iter: 190 , number of nodes: 4987
# Tree with 5152 nodes generated
# 26 path be found
# flag== 4.000000
# 4.23819462141733 73.34270146192786
# 有路径，但是这个路径从groundtruth上踏过！
#  失败次数： 5！
# ****************************************************************************************************
# n lun : 74
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 34
# Iter: 20 , number of nodes: 112
# Iter: 30 , number of nodes: 216
# Iter: 40 , number of nodes: 269
# Iter: 50 , number of nodes: 386
# Iter: 60 , number of nodes: 551
# Iter: 70 , number of nodes: 666
# Iter: 80 , number of nodes: 885
# Iter: 90 , number of nodes: 1009
# Iter: 100 , number of nodes: 1227
# Iter: 110 , number of nodes: 1416
# Iter: 120 , number of nodes: 1646
# Iter: 130 , number of nodes: 1784
# Iter: 140 , number of nodes: 1957
# Iter: 150 , number of nodes: 2084
# Iter: 160 , number of nodes: 2243
# Iter: 170 , number of nodes: 2388
# Iter: 180 , number of nodes: 2496
# Iter: 190 , number of nodes: 2608
# Tree with 2827 nodes generated
# No path found!
# because no path ::::fail=== 5.000000
# ****************************************************************************************************
# n lun : 75
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 36
# Iter: 20 , number of nodes: 136
# Iter: 30 , number of nodes: 219
# Iter: 40 , number of nodes: 352
# Iter: 50 , number of nodes: 744
# Iter: 60 , number of nodes: 1049
# Iter: 70 , number of nodes: 1324
# Iter: 80 , number of nodes: 1571
# Iter: 90 , number of nodes: 1804
# Iter: 100 , number of nodes: 2007
# Iter: 110 , number of nodes: 2286
# Iter: 120 , number of nodes: 2635
# Iter: 130 , number of nodes: 3004
# Iter: 140 , number of nodes: 3132
# Iter: 150 , number of nodes: 3405
# Iter: 160 , number of nodes: 3579
# Iter: 170 , number of nodes: 3799
# Iter: 180 , number of nodes: 4046
# Iter: 190 , number of nodes: 4287
# Tree with 4428 nodes generated
# 1 path be found
# flag== 5.000000
# 4.10124272451646 73.16021693501122
# 有路径，但是这个路径从groundtruth上踏过！
#  失败次数： 6！
# ****************************************************************************************************
# n lun : 76
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 119
# Iter: 20 , number of nodes: 313
# Iter: 30 , number of nodes: 501
# Iter: 40 , number of nodes: 719
# Iter: 50 , number of nodes: 956
# Iter: 60 , number of nodes: 1203
# Iter: 70 , number of nodes: 1427
# Iter: 80 , number of nodes: 1664
# Iter: 90 , number of nodes: 1880
# Iter: 100 , number of nodes: 2067
# Iter: 110 , number of nodes: 2348
# Iter: 120 , number of nodes: 2541
# Iter: 130 , number of nodes: 2682
# Iter: 140 , number of nodes: 2899
# Iter: 150 , number of nodes: 3040
# Iter: 160 , number of nodes: 3250
# Iter: 170 , number of nodes: 3381
# Iter: 180 , number of nodes: 3607
# Iter: 190 , number of nodes: 3747
# Tree with 3850 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 77
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 44
# Iter: 20 , number of nodes: 104
# Iter: 30 , number of nodes: 193
# Iter: 40 , number of nodes: 344
# Iter: 50 , number of nodes: 545
# Iter: 60 , number of nodes: 731
# Iter: 70 , number of nodes: 933
# Iter: 80 , number of nodes: 1079
# Iter: 90 , number of nodes: 1225
# Iter: 100 , number of nodes: 1367
# Iter: 110 , number of nodes: 1493
# Iter: 120 , number of nodes: 1599
# Iter: 130 , number of nodes: 1814
# Iter: 140 , number of nodes: 2041
# Iter: 150 , number of nodes: 2199
# Iter: 160 , number of nodes: 2487
# Iter: 170 , number of nodes: 2761
# Iter: 180 , number of nodes: 2990
# Iter: 190 , number of nodes: 3314
# Tree with 3586 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 78
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 30
# Iter: 20 , number of nodes: 62
# Iter: 30 , number of nodes: 336
# Iter: 40 , number of nodes: 505
# Iter: 50 , number of nodes: 647
# Iter: 60 , number of nodes: 888
# Iter: 70 , number of nodes: 1145
# Iter: 80 , number of nodes: 1286
# Iter: 90 , number of nodes: 1492
# Iter: 100 , number of nodes: 1610
# Iter: 110 , number of nodes: 1784
# Iter: 120 , number of nodes: 1933
# Iter: 130 , number of nodes: 2078
# Iter: 140 , number of nodes: 2344
# Iter: 150 , number of nodes: 2577
# Iter: 160 , number of nodes: 2725
# Iter: 170 , number of nodes: 2916
# Iter: 180 , number of nodes: 3198
# Iter: 190 , number of nodes: 3422
# Tree with 3565 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 79
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 97
# Iter: 20 , number of nodes: 216
# Iter: 30 , number of nodes: 402
# Iter: 40 , number of nodes: 634
# Iter: 50 , number of nodes: 803
# Iter: 60 , number of nodes: 1004
# Iter: 70 , number of nodes: 1237
# Iter: 80 , number of nodes: 1423
# Iter: 90 , number of nodes: 1585
# Iter: 100 , number of nodes: 1736
# Iter: 110 , number of nodes: 1950
# Iter: 120 , number of nodes: 2100
# Iter: 130 , number of nodes: 2219
# Iter: 140 , number of nodes: 2341
# Iter: 150 , number of nodes: 2524
# Iter: 160 , number of nodes: 2745
# Iter: 170 , number of nodes: 2931
# Iter: 180 , number of nodes: 3063
# Iter: 190 , number of nodes: 3252
# Tree with 3382 nodes generated
# 1 path be found
# flag== 6.000000
# [1.5356258051157923e-05, 5.836347153620469e-06, 7.723410333504432e-07, 1.6088847570872034e-07, 8.650010097088767e-08, 4.5426112094126836e-08, 2.50083145858504e-08, 4.799238606523204e-08, 3.43482174902654e-06, 0.000562002089169511, 0.0002538762222941693, 0.00020814901954774312, 0.00017562465490894574, 0.00015692119932519955, 0.00013744228175499584, 9.993947984904272e-05, 1.8210879576541217e-07, 2.1204149547315865e-11, 2.9690483516198185e-08, 9.420210891125658e-05, 5.355444432730838e-05, 1.24528874554386e-05, 6.929462946780873e-06, 6.563028858652675e-06, 3.9414908772905655e-06, 9.642550483635048e-07, 1.0711261455575993e-07, 7.440139060399531e-10, 1.55196966389326e-11, 1.2678746941219288e-12, 4.222566740708089e-12, 4.472089365492593e-12, 1.514027236915183e-10, 3.074240861877797e-11, 6.058376023077017e-12, 1.719427378255034e-10, 2.0183854587685346e-13, 1.201816424156732e-13, 1.9605568279956742e-09, 4.4853010194856324e-14, 0.0]
# 41
# sum: 1.300000
# sum: 2.600000
# sum: 3.900000
# sum: 5.200000
# sum: 6.500000
# sum: 7.800000
# sum: 8.450000
# sum: 9.100000
# sum: 9.200000
# sum: 10.500000
# sum: 12.300000
# sum: 14.100000
# sum: 15.900000
# sum: 17.700000
# sum: 19.500000
# sum: 21.300000
# sum: 23.100000
# sum: 24.900000
# sum: 26.700000
# sum: 28.500000
# sum: 30.300000
# sum: 32.100000
# sum: 33.900000
# sum: 35.700000
# sum: 37.500000
# sum: 39.300000
# sum: 40.486051
# sum: 41.658527
# sum: 41.892698
# sum: 42.126838
# sum: 43.426838
# sum: 44.726838
# sum: 46.026838
# sum: 47.326838
# sum: 48.626838
# sum: 49.926838
# sum: 50.576838
# sum: 51.226838
# sum: 51.326838
# sum: 51.976838
# ****************************************************************************************************
# n lun : 80
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 73
# Iter: 20 , number of nodes: 451
# Iter: 30 , number of nodes: 708
# Iter: 40 , number of nodes: 942
# Iter: 50 , number of nodes: 1107
# Iter: 60 , number of nodes: 1347
# Iter: 70 , number of nodes: 1624
# Iter: 80 , number of nodes: 1887
# Iter: 90 , number of nodes: 2124
# Iter: 100 , number of nodes: 2386
# Iter: 110 , number of nodes: 2659
# Iter: 120 , number of nodes: 2951
# Iter: 130 , number of nodes: 3196
# Iter: 140 , number of nodes: 3373
# Iter: 150 , number of nodes: 3570
# Iter: 160 , number of nodes: 3901
# Iter: 170 , number of nodes: 4219
# Iter: 180 , number of nodes: 4659
# Iter: 190 , number of nodes: 4878
# Tree with 5156 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 81
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 22
# Iter: 20 , number of nodes: 84
# Iter: 30 , number of nodes: 223
# Iter: 40 , number of nodes: 365
# Iter: 50 , number of nodes: 513
# Iter: 60 , number of nodes: 710
# Iter: 70 , number of nodes: 867
# Iter: 80 , number of nodes: 1057
# Iter: 90 , number of nodes: 1236
# Iter: 100 , number of nodes: 1447
# Iter: 110 , number of nodes: 1592
# Iter: 120 , number of nodes: 1803
# Iter: 130 , number of nodes: 1994
# Iter: 140 , number of nodes: 2163
# Iter: 150 , number of nodes: 2302
# Iter: 160 , number of nodes: 2453
# Iter: 170 , number of nodes: 2619
# Iter: 180 , number of nodes: 2782
# Iter: 190 , number of nodes: 2900
# Tree with 3008 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 82
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 49
# Iter: 20 , number of nodes: 142
# Iter: 30 , number of nodes: 215
# Iter: 40 , number of nodes: 294
# Iter: 50 , number of nodes: 377
# Iter: 60 , number of nodes: 473
# Iter: 70 , number of nodes: 537
# Iter: 80 , number of nodes: 608
# Iter: 90 , number of nodes: 732
# Iter: 100 , number of nodes: 830
# Iter: 110 , number of nodes: 959
# Iter: 120 , number of nodes: 1062
# Iter: 130 , number of nodes: 1172
# Iter: 140 , number of nodes: 1264
# Iter: 150 , number of nodes: 1399
# Iter: 160 , number of nodes: 1581
# Iter: 170 , number of nodes: 1826
# Iter: 180 , number of nodes: 1956
# Iter: 190 , number of nodes: 2087
# Tree with 2312 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 83
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 224
# Iter: 20 , number of nodes: 413
# Iter: 30 , number of nodes: 787
# Iter: 40 , number of nodes: 1134
# Iter: 50 , number of nodes: 1334
# Iter: 60 , number of nodes: 1513
# Iter: 70 , number of nodes: 1835
# Iter: 80 , number of nodes: 2128
# Iter: 90 , number of nodes: 2354
# Iter: 100 , number of nodes: 2644
# Iter: 110 , number of nodes: 2802
# Iter: 120 , number of nodes: 2999
# Iter: 130 , number of nodes: 3223
# Iter: 140 , number of nodes: 3323
# Iter: 150 , number of nodes: 3446
# Iter: 160 , number of nodes: 3593
# Iter: 170 , number of nodes: 3842
# Iter: 180 , number of nodes: 3966
# Iter: 190 , number of nodes: 4054
# Tree with 4283 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 84
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 65
# Iter: 20 , number of nodes: 229
# Iter: 30 , number of nodes: 433
# Iter: 40 , number of nodes: 590
# Iter: 50 , number of nodes: 753
# Iter: 60 , number of nodes: 943
# Iter: 70 , number of nodes: 1237
# Iter: 80 , number of nodes: 1489
# Iter: 90 , number of nodes: 1714
# Iter: 100 , number of nodes: 1948
# Iter: 110 , number of nodes: 2155
# Iter: 120 , number of nodes: 2472
# Iter: 130 , number of nodes: 2683
# Iter: 140 , number of nodes: 3008
# Iter: 150 , number of nodes: 3356
# Iter: 160 , number of nodes: 3788
# Iter: 170 , number of nodes: 4043
# Iter: 180 , number of nodes: 4264
# Iter: 190 , number of nodes: 4464
# Tree with 4660 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 85
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 34
# Iter: 20 , number of nodes: 142
# Iter: 30 , number of nodes: 215
# Iter: 40 , number of nodes: 399
# Iter: 50 , number of nodes: 656
# Iter: 60 , number of nodes: 885
# Iter: 70 , number of nodes: 1153
# Iter: 80 , number of nodes: 1320
# Iter: 90 , number of nodes: 1500
# Iter: 100 , number of nodes: 1677
# Iter: 110 , number of nodes: 1844
# Iter: 120 , number of nodes: 2056
# Iter: 130 , number of nodes: 2211
# Iter: 140 , number of nodes: 2425
# Iter: 150 , number of nodes: 2532
# Iter: 160 , number of nodes: 2640
# Iter: 170 , number of nodes: 2750
# Iter: 180 , number of nodes: 2963
# Iter: 190 , number of nodes: 3068
# Tree with 3205 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 86
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 31
# Iter: 20 , number of nodes: 53
# Iter: 30 , number of nodes: 225
# Iter: 40 , number of nodes: 317
# Iter: 50 , number of nodes: 467
# Iter: 60 , number of nodes: 779
# Iter: 70 , number of nodes: 948
# Iter: 80 , number of nodes: 1165
# Iter: 90 , number of nodes: 1567
# Iter: 100 , number of nodes: 1874
# Iter: 110 , number of nodes: 2023
# Iter: 120 , number of nodes: 2199
# Iter: 130 , number of nodes: 2377
# Iter: 140 , number of nodes: 2604
# Iter: 150 , number of nodes: 2781
# Iter: 160 , number of nodes: 2915
# Iter: 170 , number of nodes: 3127
# Iter: 180 , number of nodes: 3374
# Iter: 190 , number of nodes: 3573
# Tree with 3729 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 87
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 52
# Iter: 20 , number of nodes: 111
# Iter: 30 , number of nodes: 179
# Iter: 40 , number of nodes: 236
# Iter: 50 , number of nodes: 325
# Iter: 60 , number of nodes: 455
# Iter: 70 , number of nodes: 582
# Iter: 80 , number of nodes: 718
# Iter: 90 , number of nodes: 812
# Iter: 100 , number of nodes: 994
# Iter: 110 , number of nodes: 1130
# Iter: 120 , number of nodes: 1258
# Iter: 130 , number of nodes: 1398
# Iter: 140 , number of nodes: 1571
# Iter: 150 , number of nodes: 1724
# Iter: 160 , number of nodes: 1862
# Iter: 170 , number of nodes: 1998
# Iter: 180 , number of nodes: 2119
# Iter: 190 , number of nodes: 2304
# Tree with 2453 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 88
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 93
# Iter: 20 , number of nodes: 263
# Iter: 30 , number of nodes: 421
# Iter: 40 , number of nodes: 691
# Iter: 50 , number of nodes: 908
# Iter: 60 , number of nodes: 1141
# Iter: 70 , number of nodes: 1359
# Iter: 80 , number of nodes: 1543
# Iter: 90 , number of nodes: 1780
# Iter: 100 , number of nodes: 1966
# Iter: 110 , number of nodes: 2166
# Iter: 120 , number of nodes: 2343
# Iter: 130 , number of nodes: 2591
# Iter: 140 , number of nodes: 2796
# Iter: 150 , number of nodes: 3018
# Iter: 160 , number of nodes: 3275
# Iter: 170 , number of nodes: 3598
# Iter: 180 , number of nodes: 3815
# Iter: 190 , number of nodes: 4080
# Tree with 4378 nodes generated
# No path found!
# because no path ::::fail=== 6.000000
# ****************************************************************************************************
# n lun : 89
# Start -----------------------------1ccrrt!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 45
# Iter: 20 , number of nodes: 86
# Iter: 30 , number of nodes: 405
# Iter: 40 , number of nodes: 652
# Iter: 50 , number of nodes: 773
# Iter: 60 , number of nodes: 916

# %%
print(1111)
# Out:
# 1111

# %%
import 时刻1.time1ccrrt_sussess12

# %%
import 时刻1.time1ccrrt_sussess12

# %%
import sys
sys.path.append("../..")
sys.path.append("../../..")
from 路径规划算法.CLRRT import *
print("时刻1 CLRRT 成功率123")
def main():
    maxcc_list_100times_succ_1 = []
    mincc_list_100times_succ_1 = []
    avgcc_list_100times_succ_1 = []
    long_list_100times_succ_1 = []
    pointnumber_list_100times_succ_1 = []

    maxcc_list_100times_succ_2 = []
    mincc_list_100times_succ_2 = []
    avgcc_list_100times_succ_2 = []
    long_list_100times_succ_2 = []
    pointnumber_list_100times_succ_2 = []

    maxcc_list_100times_succ_3 = []
    mincc_list_100times_succ_3 = []
    avgcc_list_100times_succ_3 = []
    long_list_100times_succ_3 = []
    pointnumber_list_100times_succ_3 = []
    fail1 = 0
    fail2=0
    fail3=0
    cycle_times = 0
    for i in range(100):
        cycle_times += 1
        print("Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        area = [0, 15, 30, 100]  # x-min x-max y-min y-max

        # Set Initial parameters
        start = [12.25, 35, np.deg2rad(90.0)]
        goal = [9.0, 72.0, np.deg2rad(90.0)]
        car = Vehicle()
        obstacle_list_gt = [
            (5.58, 44.99, 4.12, 1.62, np.deg2rad(89.0), 2.7, 1.17),
            (5.47, 64.62, 4.4, 1.78, np.deg2rad(88.0), 2.87, 1.3),
            (9.17, 54.65, 4.17, 1.69, np.deg2rad(90.0), 2.65, 1.19),
            (12.67, 44.82, 3.88, 1.61, np.deg2rad(89.90), 2.49, 1.14),
            (12.76, 64.96, 3.95, 1.65, np.deg2rad(90.0), 2.91, 1.25),
        ]

        zhenzhi_kuang = [
            (1.9, 75.0, 4.72 / 2, 1.89 / 2, np.deg2rad(90.0)),
            (5.5, 45.0, 4.19 / 2, 1.82 / 2, np.deg2rad(90.0)),
            (5.5, 65.0, 4.79 / 2, 2.16 / 2, np.deg2rad(90.0)),
            (5.5, 95.0, 5.36 / 2, 2.03 / 2, np.deg2rad(90.0)),
            (9.1, 55.0, 4.86 / 2, 2.03 / 2, np.deg2rad(90.0)),
            (9.1, 85.0, 3.99 / 2, 1.85 / 2, np.deg2rad(90.0)),
            (12.7, 45.0, 4.18 / 2, 1.99 / 2, np.deg2rad(90.0)),
            (12.7, 65.0, 4.61 / 2, 2.24 / 2, np.deg2rad(90.0)),
        ]

        ganzhi_kuang = obstacle_uncertainty_fusion(obstacle_list_gt)
        ganzhi_tuoyuan = obstacle_uncertainty_fusion1(obstacle_list_gt)

        # Set Initial parameters
        cc_rrt = CCRRT(
            car=car,
            start=start,
            goal=goal,
            rand_area=area,
            obstacle_list=ganzhi_kuang,
            obstacle_list1=ganzhi_tuoyuan)
        # path = cc_rrt.planning(animation=False)
        cc_rrt.planning(animation=False)
        # 整理数据
        #tmp = [cc_rrt.get_chance_constrain_from_pu(node) for node in cc_rrt.path]  # 从这个可以看出这个finalpath里面都是一些节点
        tmp = cc_rrt.final_path_de_cc(cc_rrt.path)
        path_min = np.min(tmp)
        path_max = np.max(tmp)
        path_avg = np.average(tmp)
        pointnumber_list_100times_succ_1.append(len(cc_rrt.path))
        # 计算路径长度
        sum = 0
        for j in range(len(cc_rrt.path) - 1):
            changdu, _ = cc_rrt.calc_distance_and_angle(cc_rrt.path[j], cc_rrt.path[j + 1])
            sum = sum + changdu

        pengzhuang=0
        for node_in_final_path in cc_rrt.path:
            if cc_rrt.peng_zhuang_jian_ce(node_in_final_path, zhenzhi_kuang):
                # 发生碰撞
                pengzhuang = 1
                break

        if pengzhuang: #碰撞
            fail1+=1
            fail2+=1
            fail3+=1

        else : # 没有碰撞

            long_list_100times_succ_1.append(sum)
            maxcc_list_100times_succ_1.append(path_max)
            mincc_list_100times_succ_1.append(path_min)
            avgcc_list_100times_succ_1.append(path_avg)
            pointnumber_list_100times_succ_1.append(len(cc_rrt.path))

            if len(cc_rrt.path_end): # 有完整路径
                long_list_100times_succ_2.append(sum)
                maxcc_list_100times_succ_2.append(path_max)
                mincc_list_100times_succ_2.append(path_min)
                avgcc_list_100times_succ_2.append(path_avg)
                pointnumber_list_100times_succ_2.append(len(cc_rrt.path))

                # 处处risk 合格
                if path_max < 1 - cc_rrt.p_safe:
                    long_list_100times_succ_3.append(sum)
                    maxcc_list_100times_succ_3.append(path_max)
                    mincc_list_100times_succ_3.append(path_min)
                    avgcc_list_100times_succ_3.append(path_avg)
                    pointnumber_list_100times_succ_3.append(len(cc_rrt.path))
                else:
                    fail3+=1

            else: #无完整路径
                fail2+=1


        print('*' * 100)
        print("n lun : %f" % i)
    pointnumber_list_100times_succ_1 = np.array(pointnumber_list_100times_succ_1)
    long_list_100times_succ_1 = np.array(long_list_100times_succ_1)
    maxcc_list_100times_succ_1 = np.array(maxcc_list_100times_succ_1)
    mincc_list_100times_succ_1 = np.array(mincc_list_100times_succ_1)
    avgcc_list_100times_succ_1 = np.array(avgcc_list_100times_succ_1)

    pointnumber_list_100times_succ_2 = np.array(pointnumber_list_100times_succ_1)
    long_list_100times_succ_2 = np.array(long_list_100times_succ_2)
    maxcc_list_100times_succ_2 = np.array(maxcc_list_100times_succ_2)
    mincc_list_100times_succ_2 = np.array(mincc_list_100times_succ_2)
    avgcc_list_100times_succ_2 = np.array(avgcc_list_100times_succ_2)

    pointnumber_list_100times_succ_3 = np.array(pointnumber_list_100times_succ_3)
    long_list_100times_succ_3 = np.array(long_list_100times_succ_3)
    maxcc_list_100times_succ_3 = np.array(maxcc_list_100times_succ_3)
    mincc_list_100times_succ_3 = np.array(mincc_list_100times_succ_3)
    avgcc_list_100times_succ_3 = np.array(avgcc_list_100times_succ_3)
    print("standard 1")
    print("max: %f" % np.average(maxcc_list_100times_succ_1))
    print("avg: %f" % np.average(avgcc_list_100times_succ_1))
    print("min: %f" % np.average(mincc_list_100times_succ_1))
    print("points: %f" % np.average(pointnumber_list_100times_succ_1))
    print("changdu: %f" % np.average(long_list_100times_succ_1))
    print('*' * 100)
    print("fail1=:= %f" % fail1)
    print(cycle_times)
    success_rate1 = (cycle_times - fail1) / (cycle_times)
    print("success rate1: %f" % success_rate1)

    print("standard 2")
    print("max: %f" % np.average(maxcc_list_100times_succ_2))
    print("avg: %f" % np.average(avgcc_list_100times_succ_2))
    print("min: %f" % np.average(mincc_list_100times_succ_2))
    print("points: %f" % np.average(pointnumber_list_100times_succ_2))
    print("changdu: %f" % np.average(long_list_100times_succ_2))
    print('*' * 100)
    print("fail2=:= %f" % fail2)
    print(cycle_times)
    success_rate2 = (cycle_times - fail2) / (cycle_times)
    print("success rate2: %f" % success_rate2)

    print("standard 3")
    print("max: %f" % np.average(maxcc_list_100times_succ_3))
    print("avg: %f" % np.average(avgcc_list_100times_succ_3))
    print("min: %f" % np.average(mincc_list_100times_succ_3))
    print("points: %f" % np.average(pointnumber_list_100times_succ_3))
    print("changdu: %f" % np.average(long_list_100times_succ_3))
    print('*' * 100)
    print("fail3=:= %f" % fail3)
    print(cycle_times)
    success_rate3 = (cycle_times - fail3) / (cycle_times)
    print("success rate3: %f" % success_rate3)
    # plt.savefig("cc-rrt-h-fun-3.png")


if __name__ == '__main__':
    main()
# Out:
# ['/home/l/code_for_vscode/expits/exp_results_8_12/直道/计算成功率用', '', '/home/l/aws/devel/lib/python3/dist-packages', '/home/l/catkin_ws_py31/devel/lib/python3/dist-packages', '/home/l/catkin_ws_forcourse/devel/lib/python2.7/dist-packages', '/opt/ros/melodic/lib/python2.7/dist-packages', '/home/l/anaconda3/lib/python38.zip', '/home/l/anaconda3/lib/python3.8', '/home/l/anaconda3/lib/python3.8/lib-dynload', '/home/l/.local/lib/python3.8/site-packages', '/home/l/anaconda3/lib/python3.8/site-packages', '/home/l/code_for_vscode/point_perception/pointNet/pointnet.pytorch', '/home/l/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/home/l/.ipython', '../..', '../../..', '../..']
# 时刻1 CLRRT 成功率123
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Tree with 715 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 0.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 471
# Iter: 20 , number of nodes: 854
# Iter: 30 , number of nodes: 1329
# Iter: 40 , number of nodes: 1991
# Tree with 2002 nodes generated
# 7 path be found
# ****************************************************************************************************
# n lun : 1.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 818
# Tree with 1528 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 2.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Tree with 789 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 3.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 252
# Iter: 20 , number of nodes: 830
# Iter: 30 , number of nodes: 1477
# Iter: 40 , number of nodes: 1904
# Tree with 2004 nodes generated
# 15 path be found
# ****************************************************************************************************
# n lun : 4.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 205
# Iter: 20 , number of nodes: 945
# Tree with 1161 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 5.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 201
# Iter: 20 , number of nodes: 801
# Iter: 30 , number of nodes: 1251
# Tree with 1308 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 6.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 100
# Iter: 20 , number of nodes: 645
# Tree with 1097 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 7.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 337
# Tree with 831 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 8.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 103
# Tree with 680 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 9.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 414
# Tree with 1029 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 10.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 362
# Tree with 796 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 11.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 185
# Tree with 563 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 12.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 93
# Tree with 818 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 13.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 41
# Iter: 20 , number of nodes: 297
# Iter: 30 , number of nodes: 655
# Iter: 40 , number of nodes: 1186
# Tree with 1274 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 14.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 47
# Iter: 20 , number of nodes: 318
# Iter: 30 , number of nodes: 937
# Tree with 1210 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 15.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 138
# Tree with 569 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 16.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 609
# Tree with 810 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 17.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Iter: 10 , number of nodes: 40
# Iter: 20 , number of nodes: 154
# Iter: 30 , number of nodes: 690
# Iter: 40 , number of nodes: 1383
# Iter: 50 , number of nodes: 1937
# Tree with 2006 nodes generated
# 20 path be found
# ****************************************************************************************************
# n lun : 18.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
# Tree with 757 nodes generated
# 21 path be found
# ****************************************************************************************************
# n lun : 19.000000
# Start -----------------------------------1clrrt100!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Begin CC-RRT
# Iter: 0 , number of nodes: 1
